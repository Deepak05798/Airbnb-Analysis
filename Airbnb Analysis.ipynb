# %%
# !pip install pymongo
# !pip install seaborn
# !pip install matplotlib
# !pip install plotly
# Out:
# Requirement already satisfied: pymongo in c:\users\deepa\anaconda3\lib\site-packages (4.5.0)
# Requirement already satisfied: dnspython<3.0.0,>=1.16.0 in c:\users\deepa\anaconda3\lib\site-packages (from pymongo) (2.4.2)
# Requirement already satisfied: seaborn in c:\users\deepa\anaconda3\lib\site-packages (0.12.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.17 in c:\users\deepa\anaconda3\lib\site-packages (from seaborn) (1.24.3)
# Requirement already satisfied: pandas>=0.25 in c:\users\deepa\anaconda3\lib\site-packages (from seaborn) (1.5.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.1 in c:\users\deepa\anaconda3\lib\site-packages (from seaborn) (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\deepa\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\deepa\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\deepa\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\deepa\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\deepa\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (23.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\deepa\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\deepa\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\deepa\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\deepa\anaconda3\lib\site-packages (from pandas>=0.25->seaborn) (2022.7)
# Requirement already satisfied: six>=1.5 in c:\users\deepa\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.1->seaborn) (1.16.0)
# Requirement already satisfied: matplotlib in c:\users\deepa\anaconda3\lib\site-packages (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\deepa\anaconda3\lib\site-packages (from matplotlib) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\deepa\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\deepa\anaconda3\lib\site-packages (from matplotlib) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\deepa\anaconda3\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: numpy>=1.20 in c:\users\deepa\anaconda3\lib\site-packages (from matplotlib) (1.24.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\deepa\anaconda3\lib\site-packages (from matplotlib) (23.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\deepa\anaconda3\lib\site-packages (from matplotlib) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\deepa\anaconda3\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\deepa\anaconda3\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\deepa\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %%
import pandas as pd
import pymongo
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px

# %%
client = pymongo.MongoClient('Unique string connection')
db = client.sample_airbnb
col = db.listingsAndReviews

# %%
rel_data = []
for i in col.find():
    data = dict(Id = i['_id'],
                Listing_url = i['listing_url'],
                Name = i.get('name'),
                Description = i['description'],
                House_rules = i.get('house_rules'),
                Property_type = i['property_type'],
                Room_type = i['room_type'],
                Bed_type = i['bed_type'],
                Min_nights = int(i['minimum_nights']),
                Max_nights = int(i['maximum_nights']),
                Cancellation_policy = i['cancellation_policy'],
                Accomodates = i['accommodates'],
                Total_bedrooms = i.get('bedrooms'),
                Total_beds = i.get('beds'),
                Availability_365 = i['availability']['availability_365'],
                Price = i['price'],
                Security_deposit = i.get('security_deposit'),
                Cleaning_fee = i.get('cleaning_fee'),
                Extra_people = i['extra_people'],
                Guests_included= i['guests_included'],
                No_of_reviews = i['number_of_reviews'],
                Review_scores = i['review_scores'].get('review_scores_rating'),
                Amenities = ', '.join(i['amenities']),
                Host_id = i['host']['host_id'],
                Host_name = i['host']['host_name'],
                Street = i['address']['street'],
                Country = i['address']['country'],
                Country_code = i['address']['country_code'],
                Location_type = i['address']['location']['type'],
                Longitude = i['address']['location']['coordinates'][0],
                Latitude = i['address']['location']['coordinates'][1],
                Is_location_exact = i['address']['location']['is_location_exact']
    )
    rel_data.append(data)

# %%
df = pd.DataFrame(rel_data)
df
# Out:
#             Id                            Listing_url  \
# 0     10006546  https://www.airbnb.com/rooms/10006546
# 1     10009999  https://www.airbnb.com/rooms/10009999
# 2      1001265   https://www.airbnb.com/rooms/1001265
# 3     10021707  https://www.airbnb.com/rooms/10021707
# 4     10030955  https://www.airbnb.com/rooms/10030955
# ...        ...                                    ...
# 5550   9983221   https://www.airbnb.com/rooms/9983221
# 5551   9985696   https://www.airbnb.com/rooms/9985696
# 5552   9987200   https://www.airbnb.com/rooms/9987200
# 5553   9990304   https://www.airbnb.com/rooms/9990304
# 5554   9993190   https://www.airbnb.com/rooms/9993190
#
#                                                    Name  \
# 0                               Ribeira Charming Duplex
# 1                          Horto flat with small garden
# 2                      Ocean View Waikiki Marina w/prkg
# 3                              Private Room in Bushwick
# 4                           Apt Linda Vista Lagoa - Rio
# ...                                                 ...
# 5550                      Cozy apartment downtown Porto
# 5551                                    Kadıköy-Altıyol
# 5552       The best suite in Copacabana (total privacy)
# 5553     March Madness Special! Aina Nalu Platinum D107
# 5554  Just Steps from the Ocean at Premier Platinum ...
#
#                                             Description  \
# 0     Fantastic duplex apartment with three bedrooms...
# 1     One bedroom + sofa-bed in quiet and bucolic ne...
# 2     A short distance from Honolulu's billion dolla...
# 3     Here exists a very cozy room for rent in a sha...
# 4     Quarto com vista para a Lagoa Rodrigo de Freit...
# ...                                                 ...
# 5550  Renovated, fully equipped, within walking dist...
# 5551  Kadıköy merkezde 2+1 dairem vardır.Çok kalabal...
# 5552  Excellent private suite with bathroom at the A...
# 5553  Walk out to Saltwater Infinity Pool! Call us N...
# 5554  Relax Hawaiian Style in Gated Community on Oce...
#
#                                             House_rules Property_type  \
# 0                           Make the house your home...         House
# 1     I just hope the guests treat the space as they...     Apartment
# 2     The general welfare and well being of all the ...   Condominium
# 3                                                           Apartment
# 4                                                           Apartment
# ...                                                 ...           ...
# 5550  Non smoking.  The hosts are supposed to leave ...     Apartment
# 5551                                                            House
# 5552                            Checked-in guests only.    Aparthotel
# 5553  As a guest of Coconut Condos, I agree to the f...   Condominium
# 5554  As a guest of Coconut Condos, I agree to the f...     Townhouse
#
#             Room_type  Bed_type  Min_nights  Max_nights  ...  \
# 0     Entire home/apt  Real Bed           2          30  ...
# 1     Entire home/apt  Real Bed           2        1125  ...
# 2     Entire home/apt  Real Bed           3         365  ...
# 3        Private room  Real Bed          14        1125  ...
# 4        Private room  Real Bed           1        1125  ...
# ...               ...       ...         ...         ...  ...
# 5550  Entire home/apt  Real Bed           3        1125  ...
# 5551  Entire home/apt  Real Bed           1        1125  ...
# 5552     Private room  Real Bed           3          60  ...
# 5553  Entire home/apt  Real Bed           3         365  ...
# 5554  Entire home/apt  Real Bed           3         365  ...
#
#                                               Amenities   Host_id  \
# 0     TV, Cable TV, Wifi, Kitchen, Paid parking off ...  51399391
# 1     Wifi, Wheelchair accessible, Kitchen, Free par...   1282196
# 2     TV, Cable TV, Wifi, Air conditioning, Pool, Ki...   5448114
# 3     Internet, Wifi, Air conditioning, Kitchen, Buz...  11275734
# 4     TV, Cable TV, Internet, Wifi, Air conditioning...  51496939
# ...                                                 ...       ...
# 5550  TV, Cable TV, Internet, Wifi, Kitchen, Paid pa...  37776205
# 5551  TV, Cable TV, Internet, Wifi, Kitchen, Buzzer/...  51303748
# 5552  TV, Cable TV, Wifi, Air conditioning, Pool, Gy...  51314789
# 5553  TV, Cable TV, Wifi, Air conditioning, Wheelcha...  51013381
# 5554  TV, Wifi, Air conditioning, Pool, Kitchen, Fre...  51013381
#
#            Host_name                                  Street        Country  \
# 0        Ana&Gonçalo                  Porto, Porto, Portugal       Portugal
# 1              Ynaie  Rio de Janeiro, Rio de Janeiro, Brazil         Brazil
# 2              David             Honolulu, HI, United States  United States
# 3               Josh             Brooklyn, NY, United States  United States
# 4              Livia  Rio de Janeiro, Rio de Janeiro, Brazil         Brazil
# ...              ...                                     ...            ...
# 5550             Ana                  Porto, Porto, Portugal       Portugal
# 5551            Eren               Kadıköy, İstanbul, Turkey         Turkey
# 5552          Dumont  Rio de Janeiro, Rio de Janeiro, Brazil         Brazil
# 5553  Coconut Condos              Lahaina, HI, United States  United States
# 5554  Coconut Condos              Lahaina, HI, United States  United States
#
#      Country_code Location_type   Longitude   Latitude Is_location_exact
# 0              PT         Point   -8.613080  41.141300             False
# 1              BR         Point  -43.230750 -22.966254              True
# 2              US         Point -157.839190  21.286340              True
# 3              US         Point  -73.936150  40.697910              True
# 4              BR         Point  -43.205047 -22.971951              True
# ...           ...           ...         ...        ...               ...
# 5550           PT         Point   -8.616930  41.151370             False
# 5551           TR         Point   29.030790  40.985630             False
# 5552           BR         Point  -43.176533 -22.961076              True
# 5553           US         Point -156.676460  20.875610             False
# 5554           US         Point -156.667520  20.858940             False
#
# [5555 rows x 32 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5555 entries, 0 to 5554
# Data columns (total 32 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Id                   5555 non-null   object
#  1   Listing_url          5555 non-null   object
#  2   Name                 5555 non-null   object
#  3   Description          5555 non-null   object
#  4   House_rules          5555 non-null   object
#  5   Property_type        5555 non-null   object
#  6   Room_type            5555 non-null   object
#  7   Bed_type             5555 non-null   object
#  8   Min_nights           5555 non-null   int64
#  9   Max_nights           5555 non-null   int64
#  10  Cancellation_policy  5555 non-null   object
#  11  Accomodates          5555 non-null   int64
#  12  Total_bedrooms       5550 non-null   float64
#  13  Total_beds           5542 non-null   float64
#  14  Availability_365     5555 non-null   int64
#  15  Price                5555 non-null   object
#  16  Security_deposit     3471 non-null   object
#  17  Cleaning_fee         4024 non-null   object
#  18  Extra_people         5555 non-null   object
#  19  Guests_included      5555 non-null   object
#  20  No_of_reviews        5555 non-null   int64
#  21  Review_scores        4081 non-null   float64
#  22  Amenities            5555 non-null   object
#  23  Host_id              5555 non-null   object
#  24  Host_name            5555 non-null   object
#  25  Street               5555 non-null   object
#  26  Country              5555 non-null   object
#  27  Country_code         5555 non-null   object
#  28  Location_type        5555 non-null   object
#  29  Longitude            5555 non-null   float64
#  30  Latitude             5555 non-null   float64
#  31  Is_location_exact    5555 non-null   bool
# dtypes: bool(1), float64(5), int64(5), object(21)
# memory usage: 1.3+ MB

# %%
df.Price = df.Price.astype(str).astype(float)
df.Security_deposit = df.Security_deposit[~df.Security_deposit.isna()].astype(str).astype(float)
df.Cleaning_fee = df.Cleaning_fee[~df.Cleaning_fee.isna()].astype(str).astype(float)
df.Extra_people = df.Extra_people.astype(str).astype(float)
df.Guests_included = df.Guests_included.astype(str).astype(float)
df.Review_scores = df.Review_scores.astype('Int64')

# %%
df.isna().sum()
# Out:
# Id                        0
# Listing_url               0
# Name                      0
# Description               0
# House_rules               0
# Property_type             0
# Room_type                 0
# Bed_type                  0
# Min_nights                0
# Max_nights                0
# Cancellation_policy       0
# Accomodates               0
# Total_bedrooms            0
# Total_beds                0
# Availability_365          0
# Price                     0
# Security_deposit       2084
# Cleaning_fee           1531
# Extra_people              0
# Guests_included           0
# No_of_reviews             0
# Review_scores          1474
# Amenities                 0
# Host_id                   0
# Host_name                 0
# Street                    0
# Country                   0
# Country_code              0
# Location_type             0
# Longitude                 0
# Latitude                  0
# Is_location_exact         0
# dtype: int64

# %%
df.Total_bedrooms.fillna(df.Total_bedrooms.mode()[0],inplace=True)
df.Total_beds.fillna(df.Total_beds.median(),inplace=True)
df.Security_deposit .fillna(df.Security_deposit.median(),inplace=True)
df.Review_scores.fillna(df.Review_scores.median(),inplace=True)
df.Cleaning_fee.fillna(df.Cleaning_fee.median(),inplace=True)

# %%
df.Description.replace(to_replace ='',value ='Not provided',inplace=True)
df.House_rules.replace(to_replace = '',value = 'Not provided',inplace=True)
df.Amenities.replace(to_replace = '',value = 'Not avalible',inplace = True)

# %%
df.isna().sum()
# Out:
# Id                     0
# Listing_url            0
# Name                   0
# Description            0
# House_rules            0
# Property_type          0
# Room_type              0
# Bed_type               0
# Min_nights             0
# Max_nights             0
# Cancellation_policy    0
# Accomodates            0
# Total_bedrooms         0
# Total_beds             0
# Availability_365       0
# Price                  0
# Security_deposit       0
# Cleaning_fee           0
# Extra_people           0
# Guests_included        0
# No_of_reviews          0
# Review_scores          0
# Amenities              0
# Host_id                0
# Host_name              0
# Street                 0
# Country                0
# Country_code           0
# Location_type          0
# Longitude              0
# Latitude               0
# Is_location_exact      0
# dtype: int64

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Id, Listing_url, Name, Description, House_rules, Property_type, Room_type, Bed_type, Min_nights, Max_nights, Cancellation_policy, Accomodates, Total_bedrooms, Total_beds, Availability_365, Price, Security_deposit, Cleaning_fee, Extra_people, Guests_included, No_of_reviews, Review_scores, Amenities, Host_id, Host_name, Street, Country, Country_code, Location_type, Longitude, Latitude, Is_location_exact]
# Index: []
#
# [0 rows x 32 columns]

# %%
df.drop(labels=list(df[df.Name.duplicated(keep=False)].index),inplace=True)

# %%
df.reset_index(drop=True,inplace=True)

# %%
df.to_csv('airbnb_data.csv',index=False)

# %%
plt.figure(figsize=(10,8))
ax = sns.countplot(data=df,y=df.Property_type.values,order=df.Property_type.value_counts().index[:10])
ax.set_title("Top 10 Property Types available")
# Out:
# Text(0.5, 1.0, 'Top 10 Property Types available')

# %%
plt.figure(figsize=(5,10))
ax = sns.countplot(data =df,x=df.Room_type)
ax.set_title('total Room type')
# Out:
# Text(0.5, 1.0, 'total Room type')

# %%
plt.figure(figsize=(10,8))
ax = sns.countplot(data=df,y=df.Host_name,order=df.Host_name.value_counts().index[:10])
ax.set_title("Top 10 Hosts with Highest number of Listings")
# Out:
# Text(0.5, 1.0, 'Top 10 Hosts with Highest number of Listings')

# %%
fig = px.choropleth(data_frame=df,
                    locations='Country_code',
                    color='Country',
                    locationmode='country names')
fig.show()
# Out:
# <div>                            <div id="6a781fda-6a41-4c41-99df-959a95138501" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6a781fda-6a41-4c41-99df-959a95138501")) {                    Plotly.newPlot(                        "6a781fda-6a41-4c41-99df-959a95138501",                        [{"colorscale": [[0.0, "#636efa"], [1.0, "#636efa"]], "geo": "geo", "hovertemplate": "Country=Portugal<br>Country_code=%{location}<extra></extra>", "locationmode": "country names", "locations": ["PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", "PT", ...

# %%
country_df = df.groupby('Country',as_index=False)['Price'].mean()

# %%
fig = px.scatter(data_frame=country_df,
           x='Country',y='Price',
           color='Country',
           size='Price',
           opacity=1,
           size_max=20,
           title='Avg Listing Price in each Countries')
fig.show()
# Out:
# <div>                            <div id="4626b812-f492-4372-8afc-2711c0fb248c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4626b812-f492-4372-8afc-2711c0fb248c")) {                    Plotly.newPlot(                        "4626b812-f492-4372-8afc-2711c0fb248c",                        [{"hovertemplate": "Country=%{x}<br>Price=%{marker.size}<extra></extra>", "legendgroup": "Australia", "marker": {"color": "#636efa", "opacity": 1, "size": [197.8065573770492], "sizemode": "area", "sizeref": 1.9338127090301003, "symbol": "circle"}, "mode": "markers", "name": "Australia", "orientation": "v", "showlegend": true, "type": "scatter", "x": ["Australia"], "xaxis": "x", "y": [197.8065573770492], "yaxis": "y"}, {"hovertemplate": "Country=%{x}<br>Price=%{marker.size}<extra></extra>", "legendgroup": "Brazil", "marker": {"color": "#EF553B", "opacity": 1, "size": [525.801652892562], "sizemode": "area", "sizeref": 1.9338127090301003, "symbol": "circle"}, "mode": "markers", "name": "Brazil", "orientation": "v", "showlegend": true, "type": "scatter", "x": ["Brazil"], "xaxis": "x", "y": [525.801652892562], "yaxis": "y"}, {"hovertemplate": "Country=%{x}<br>Price=%{marker.size}<extra></extra>", "legendgroup": "Canada", "marker": {"color": "#00cc96", "opacity": 1, "size": [100.04798761609906], "sizemode": "area", "sizeref": 1.9338127090301003, "symbol": "circle"}, "mode": "markers", "name": "Canada", "orientation": "v", "showlegend": true, "type": "scatter", "x": ["Canada"], "xaxis": "x", "y": [100.04798761609906], "yaxis": "y"}, {"hovertemplate": "Country=%{x}<br>Price=%{marker.size}<extra></extra>", "legendgroup": "China", "marker": {"color": "#ab63fa", "opacity": 1, "size": [405.36842105263156], "sizemode": "area", "sizeref": 1.9338127090301003, "symbol": "circle"}, "mode": "markers", "name": "China", "orientation": "v", "showlegend": true, "type": "scatter", "x": ["China"], "xaxis": "x", "y": [405.36842105263156], "yaxis": "y"}, {"hovertemplate": "Country=%{x}<br>Price=%{marker.size}<extra></extra>", "legendgroup": "Hong Kong", "marker": {"color": "#FFA15A", "opacity": 1, "size": [773.5250836120401], "sizemode": "area", "sizeref": 1.9338127090301003, "symbol": "circle"}, "mode": "markers", "name": "Hong Kong", "orientation": "v", "showlegend": true, "type": "scatter", "x": ["Hong Kong"], "xaxis": "x", "y": [773.5250836120401], "yaxis": "y"}, {"hovertemplate": "Country=%{x}<br>Price=%{marker.size}<extra></extra>", "legendgroup": "Portugal", "marker": {"color": "#19d3f3", "opacity": 1, "size": [69.50181818181818], "sizemode": "area", "sizeref": 1.9338127090301003, "symbol": "circle"}, "mode": "markers", "name": "Portugal", "orientation": "v", "showlegend": true, "type": "scatter", "x": ["Portugal"], "xaxis": "x", "y": [69.50181818181818], "yaxis": "y"}, {"hovertemplate": "Country=%{x}<br>Price=%{marker.size}<extra></extra>", "legendgroup": "Spain", "marker": {"color": "#FF6692", "opacity": 1, "size": [101.00792393026941], "sizemode": "area", "sizeref": 1.9338127090301003, "symbol": "circle"}, "mode": "markers", "name": "Spain", "orientation": "v", "showlegend": true, "type": "scatter", "x": ["Spain"], "xaxis": "x", "y": [101.00792393026941], "yaxis": "y"}, {"hovertemplate": "Country=%{x}<br>Price=%{marker.size}<extra></extra>", "legendgroup": "Turkey", "marker": {"color": "#B6E880", "opacity": 1, "size": [371.1984615384615], "sizemode": "area", "sizeref": 1.9338127090301003, "symbol": "circle"}, "mode": "markers", "name": "Turkey", "orientation": "v", "showlegend": true, "type": "scatter", "x": ["Turkey"], "xaxis": "x", "y": [371.1984615384615], "yaxis": "y"}, {"hovertemplate": "Country=%{x}<br>Price=%{marker.size}<extra></extra>", "legendgroup": "United States", "marker": {"color": "#FF97FF", "opacity": 1, " ...

# %%
rev_df = df.groupby('Room_type',as_index=False)['Review_scores'].mean().sort_values(by='Review_scores')
fig = px.bar(data_frame=rev_df,x='Room_type',y='Review_scores',color='Review_scores')
fig.show()
# Out:
# <div>                            <div id="f0fca413-5a49-4da8-be81-99f7e5ca4a56" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f0fca413-5a49-4da8-be81-99f7e5ca4a56")) {                    Plotly.newPlot(                        "f0fca413-5a49-4da8-be81-99f7e5ca4a56",                        [{"alignmentgroup": "True", "hovertemplate": "Room_type=%{x}<br>Review_scores=%{marker.color}<extra></extra>", "legendgroup": "", "marker": {"color": [92.57831325301204, 93.28252032520325, 93.85365152386429], "coloraxis": "coloraxis"}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "textposition": "auto", "type": "bar", "x": ["Shared room", "Private room", "Entire home/apt"], "xaxis": "x", "y": [92.57831325301204, 93.28252032520325, 93.85365152386429], "yaxis": "y"}],                        {"barmode": "relative", "coloraxis": {"colorbar": {"title": {"text": "Review_scores"}}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]]}, "legend": {"tracegroupgap": 0}, "margin": {"t": 60}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth" ...

# %%
pr_df = df.groupby('Room_type',as_index=False)['Price'].mean().sort_values(by='Price')
fig = px.bar(data_frame=pr_df,x='Room_type',y='Price',color='Price')
fig.show()
# Out:
# <div>                            <div id="e37ec74e-88dd-4640-ab85-db653ea703b4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e37ec74e-88dd-4640-ab85-db653ea703b4")) {                    Plotly.newPlot(                        "e37ec74e-88dd-4640-ab85-db653ea703b4",                        [{"alignmentgroup": "True", "hovertemplate": "Room_type=%{x}<br>Price=%{marker.color}<extra></extra>", "legendgroup": "", "marker": {"color": [212.640243902439, 315.1155836687752, 349.5903614457831], "coloraxis": "coloraxis"}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "textposition": "auto", "type": "bar", "x": ["Private room", "Entire home/apt", "Shared room"], "xaxis": "x", "y": [212.640243902439, 315.1155836687752, 349.5903614457831], "yaxis": "y"}],                        {"barmode": "relative", "coloraxis": {"colorbar": {"title": {"text": "Price"}}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]]}, "legend": {"tracegroupgap": 0}, "margin": {"t": 60}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, ...
